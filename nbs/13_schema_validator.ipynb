# %%
# | default_exp schema_validator

# %% [markdown]
# # Schema Validator
# > Validate structured data (JSON-LD) against schema.org definitions.

# %%
# | export
from __future__ import annotations
import json
import re
from typing import Any
import requests
from bs4 import BeautifulSoup

# %%
# | export

# Google Rich Results spec: required and recommended fields per type
# Source: http://developers.google.com/search/docs/appearance/structured-data/search-gallery
GOOGLE_SPEC: dict[str, dict[str, list[str]]] = {
    "Article": {
        "required": ["@type", "headline", "image", "datePublished", "author"],
        "recommended": ["dateModified", "author.@type", "author.name", "publisher", "publisher.@type",
                        "publisher.name"],
    },
    "NewsArticle": {
        "required": ["@type", "headline", "image", "datePublished", "author"],
        "recommended": ["dateModified", "author.name", "publisher", "publisher.name"],
    },
    "BlogPosting": {
        "required": ["@type", "headline", "image", "datePublished", "author"],
        "recommended": ["dateModified", "author.name", "publisher", "publisher.name"],
    },
    "BreadcrumbList": {
        "required": ["@type", "itemListElement"],
        "recommended": ["itemListElement.@type", "itemListElement.position", "itemListElement.name",
                        "itemListElement.item"],
    },
    "Course": {
        "required": ["@type", "name", "description", "provider"],
        "recommended": ["provider.@type", "provider.name", "url", "hasCourseInstance"],
    },
    "Dataset": {
        "required": ["@type", "name", "description"],
        "recommended": ["url", "sameAs", "keywords", "creator", "license", "temporalCoverage", "spatialCoverage"],
    },
    "DiscussionForumPosting": {
        "required": ["@type", "headline", "url", "author"],
        "recommended": ["datePublished", "text", "author.name"],
    },
    "EmployerAggregateRating": {
        "required": ["@type", "itemReviewed", "ratingValue", "bestRating", "worstRating", "ratingCount"],
        "recommended": ["itemReviewed.name", "itemReviewed.sameAs"],
    },
    "Event": {
        "required": ["@type", "name", "startDate", "location"],
        "recommended": ["endDate", "description", "image", "organizer", "performer", "eventStatus",
                        "eventAttendanceMode", "offers"],
    },
    "FAQPage": {
        "required": ["@type", "mainEntity"],
        "recommended": ["mainEntity.@type", "mainEntity.name", "mainEntity.acceptedAnswer",
                        "mainEntity.acceptedAnswer.text"],
    },
    "ImageObject": {
        "required": ["@type", "contentUrl"],
        "recommended": ["license", "acquireLicensePage", "creditText", "creator", "copyrightNotice"],
    },
    "JobPosting": {
        "required": ["@type", "title", "description", "hiringOrganization", "jobLocation", "datePosted"],
        "recommended": ["validThrough", "employmentType", "baseSalary", "hiringOrganization.name",
                        "hiringOrganization.sameAs"],
    },
    "LocalBusiness": {
        "required": ["@type", "name", "address"],
        "recommended": ["address.@type", "address.streetAddress", "address.addressLocality", "address.addressCountry",
                        "telephone", "url", "openingHours", "geo", "priceRange", "image"],
    },
    "MathSolver": {
        "required": ["@type", "name", "potentialAction"],
        "recommended": ["potentialAction.@type", "potentialAction.mathExpression"],
    },
    "Movie": {
        "required": ["@type", "name"],
        "recommended": ["url", "image", "director", "dateCreated", "genre", "description", "aggregateRating"],
    },
    "Organization": {
        "required": ["@type", "name", "url", "logo"],
        "recommended": ["contactPoint", "sameAs", "address", "telephone", "foundingDate", "numberOfEmployees"],
    },
    "Product": {
        "required": ["@type", "name"],
        "recommended": ["image", "description", "sku", "brand", "offers", "aggregateRating", "review"],
    },
    "ProfilePage": {
        "required": ["@type", "mainEntity"],
        "recommended": ["mainEntity.@type", "mainEntity.name", "mainEntity.description", "mainEntity.image"],
    },
    "QAPage": {
        "required": ["@type", "mainEntity"],
        "recommended": ["mainEntity.@type", "mainEntity.name", "mainEntity.acceptedAnswer",
                        "mainEntity.suggestedAnswer"],
    },
    "Recipe": {
        "required": ["@type", "name", "image", "author", "datePublished", "description", "recipeIngredient",
                     "recipeInstructions"],
        "recommended": ["prepTime", "cookTime", "totalTime", "recipeYield", "nutrition", "aggregateRating", "video"],
    },
    "Review": {
        "required": ["@type", "itemReviewed", "reviewRating", "author"],
        "recommended": ["reviewRating.ratingValue", "reviewRating.bestRating", "author.name", "reviewBody",
                        "publisher"],
    },
    "AggregateRating": {
        "required": ["@type", "ratingValue", "reviewCount"],
        "recommended": ["bestRating", "worstRating", "itemReviewed"],
    },
    "SoftwareApplication": {
        "required": ["@type", "name", "operatingSystem", "applicationCategory"],
        "recommended": ["offers", "aggregateRating", "offers.price", "offers.priceCurrency"],
    },
    "SpeakableSpecification": {
        "required": ["@type", "cssSelector"],
        "recommended": ["xpath"],
    },
    "VacationRental": {
        "required": ["@type", "name", "description", "url"],
        "recommended": ["image", "address", "geo", "telephone", "aggregateRating", "numberOfRooms"],
    },
    "VideoObject": {
        "required": ["@type", "name", "description", "thumbnailUrl", "uploadDate"],
        "recommended": ["duration", "contentUrl", "embedUrl", "expires", "hasPart", "watchAction", "publication"],
    },
    "WebPage": {
        "required": ["@type", "name"],
        "recommended": ["url", "description", "breadcrumb", "lastReviewed"],
    },
    "WebSite": {
        "required": ["@type", "url"],
        "recommended": ["name", "potentialAction", "potentialAction.@type", "potentialAction.target",
                        "potentialAction.query-input"],
    },
    "Person": {
        "required": ["@type", "name"],
        "recommended": ["url", "image", "jobTitle", "worksFor", "sameAs"],
    },
    "ItemList": {
        "required": ["@type", "itemListElement"],
        "recommended": ["itemListElement.@type", "itemListElement.position", "itemListElement.url"],
    },
}

GOOGLE_SUPPORTED_TYPES: set[str] = set(GOOGLE_SPEC.keys())

# %%
# | export
import httpx


def fetch_html(url: str,  # URL to fetch
               timeout: int = 10  # Request timeout in seconds
               ) -> tuple[str, int]:
    "Fetch raw HTML from a live URL. Returns (html, status_code)."
    try:
        resp = httpx.get(url, headers={"User-Agent": "Mozilla/5.0 (compatible; seo-rat-schema-validator/1.0)"},
                         timeout=timeout)
        return resp.text, resp.status_code
    except httpx.RequestError:
        return "", 0

# %%
# | export

def _get_nested(obj: dict,  # Schema dict to traverse
                dotpath: str  # Dot-notated field path e.g. 'author.name'
                ) -> Any:
    "Get a value from a nested dict using dot notation, handling lists by checking first element."
    current = obj
    for part in dotpath.split("."):
        if isinstance(current, list): current = current[0] if current else None
        if not isinstance(current, dict): return None
        current = current.get(part)
    return current


def _field_present(schema: dict,  # Schema dict
                   field: str  # Field name or dot-notated path
                   ) -> bool:
    "Check if a field is present and non-empty in a schema dict."
    val = _get_nested(schema, field)
    return bool(val) if val is not None else False


def extract_jsonld_schemas(html: str) -> list[dict]:
    """Extract all JSON-LD schema blocks from HTML. Returns list of parsed dicts."""
    soup = BeautifulSoup(html, "html.parser")
    schemas = []
    for tag in soup.find_all("script", type="application/ld+json"):
        try:
            data = json.loads(tag.string or "")
            # Handle @graph arrays
            if isinstance(data, dict) and "@graph" in data:
                for item in data["@graph"]:
                    schemas.append({"format": "json-ld", "raw": item})
            elif isinstance(data, list):
                for item in data:
                    schemas.append({"format": "json-ld", "raw": item})
            elif isinstance(data, dict):
                schemas.append({"format": "json-ld", "raw": data})
        except (json.JSONDecodeError, TypeError):
            continue
    return schemas


def extract_microdata_schemas(html: str  # Raw HTML content
                              ) -> list[dict]:
    "Extract Microdata itemscope blocks from HTML as flat dicts."
    soup = BeautifulSoup(html, "html.parser")
    schemas = []
    for item in soup.find_all(attrs={"itemscope": True, "itemtype": True}):
        itemtype = item.get("itemtype", "")
        raw = {"@type": itemtype.split("/")[-1] if itemtype else ""}
        for prop in item.find_all(attrs={"itemprop": True}):
            if name := prop.get("itemprop"):
                raw[name] = (prop.get("content") or
                             prop.get("href") or
                             prop.get_text(strip=True))
        schemas.append({"format": "microdata", "raw": raw})
    return schemas


def extract_schemas(html: str) -> list[dict]:
    """Extract all schema blocks (JSON-LD + Microdata) from HTML."""
    return extract_jsonld_schemas(html) + extract_microdata_schemas(html)

# %%
# | export

def validate_schema(schema_block: dict  # Dict with 'format' and 'raw' keys
                    ) -> dict:
    "Validate a single schema block against Google's rich result spec."
    raw = schema_block.get("raw", {})
    fmt = schema_block.get("format", "unknown")

    raw_type = raw.get("@type", "")
    if isinstance(raw_type, list): raw_type = next(iter(raw_type), "")
    schema_type = raw_type.replace("https://schema.org/", "").replace("http://schema.org/", "")

    google_supported = schema_type in GOOGLE_SUPPORTED_TYPES
    spec = GOOGLE_SPEC.get(schema_type, {"required": [], "recommended": []})

    missing_required = [f for f in spec["required"] if not _field_present(raw, f)]
    missing_recommended = [f for f in spec["recommended"] if not _field_present(raw, f)]
    fields_present = [f for f in spec["required"] + spec["recommended"] if _field_present(raw, f)]

    warning_checks = [
        (not schema_type,
         "@type is missing — Google cannot identify this schema"),
        (not google_supported and schema_type,
         f"'{schema_type}' is not a Google rich result type — no rich snippet will be generated"),
        (isinstance(raw.get("image"), str) and schema_type in ("Article", "Recipe", "VideoObject"),
         "'image' should be an ImageObject or array, not a bare string"),
        (schema_type == "Article" and isinstance(raw.get("author"), str),
         "'author' should be a Person or Organization object, not a bare string"),
        (schema_type == "LocalBusiness" and not raw.get("@id"),
         "'@id' is missing — recommended for LocalBusiness to enable knowledge panel"),
        (schema_type == "FAQPage" and isinstance(raw.get("mainEntity"), list) and not raw.get("mainEntity"),
         "'mainEntity' is empty — FAQPage needs at least one Question"),
    ]
    warnings = [msg for condition, msg in warning_checks if condition]

    return {"format": fmt, "type": schema_type or "(unknown)",
            "google_supported": google_supported,
            "is_valid": not missing_required and bool(schema_type),
            "all_fields_in_raw": list(raw.keys()),
            "fields_present_from_spec": fields_present,
            "fields_missing_required": missing_required,
            "fields_missing_recommended": missing_recommended,
            "warnings": warnings, "raw": raw}

# %%
# | export

def validate_page(url: str,  # Live page URL to validate
                  timeout: int = 10  # HTTP request timeout in seconds
                  ) -> dict:
    "Fetch a live URL and validate all schema.org markup found on the page."
    html, status = fetch_html(url, timeout=timeout)
    if not html:
        return {"url": url, "fetch_status": status, "error": "Failed to fetch page",
                "schemas_found": [],
                "summary": {"total_schemas": 0, "valid_count": 0, "types_found": [], "has_google_supported": False}}
    validated = [validate_schema(s) for s in extract_schemas(html)]
    return {"url": url, "fetch_status": status, "schemas_found": validated,
            "summary": {"total_schemas": len(validated),
                        "valid_count": sum(1 for v in validated if v["is_valid"]),
                        "types_found": [v["type"] for v in validated],
                        "has_google_supported": any(v["google_supported"] for v in validated)}}

# %%
# | export

def validate_pages(urls: list[str],  # List of page URLs to validate
                   timeout: int = 10  # HTTP request timeout in seconds
                   ) -> list[dict]:
    "Validate schema markup for a list of URLs."
    return [validate_page(url, timeout=timeout) for url in urls]

# %%
# | hide
#| eval: false
result = validate_page("http://localhost:4321/")
print("Status:", result["fetch_status"])
print("Summary:", result["summary"])
# Out:
# Status: 0
# Summary: {'total_schemas': 0, 'valid_count': 0, 'types_found': [], 'has_google_supported': False}

# %%
# | hide
#| eval: false
for schema in result["schemas_found"]:
    print(f"\n--- Type: {schema['type']} ({schema['format']}) ---")
    print(f"  Google supported : {schema['google_supported']}")
    print(f"  Valid            : {schema['is_valid']}")
    print(f"  Fields in raw    : {schema['all_fields_in_raw']}")
    print(f"  Present (spec)   : {schema['fields_present_from_spec']}")
    print(f"  Missing required : {schema['fields_missing_required']}")
    print(f"  Missing recmd    : {schema['fields_missing_recommended']}")
    if schema['warnings']:
        print(f"  ⚠ Warnings       : {schema['warnings']}")

# %%
#| hide
#| eval: false
import requests
from bs4 import BeautifulSoup

r = requests.get("http://127.0.0.1:5001/sitemap.xml")
soup = BeautifulSoup(r.text, "xml")
urls = [loc.text for loc in soup.find_all("loc")]
print(f"Total URLs: {len(urls)}")
urls
# Out:
# Total URLs: 63
# ['https://gpuvec.com/',
#  'https://gpuvec.com/posts',
#  'https://gpuvec.com/gpus',
#  'https://gpuvec.com/providers',
#  'https://gpuvec.com/tools',
#  'https://gpuvec.com/tools/gpu-comparison',
#  'https://gpuvec.com/tools/model-size-calculator',
#  'https://gpuvec.com/tools/cost-estimator',
#  'https://gpuvec.com/compute_capability',
#  'https://gpuvec.com/tools/vector-database',
#  'https://gpuvec.com/tools/provider-comparison',
#  'https://gpuvec.com/tools/inference-comparison',
#  'https://gpuvec.com/tools/performance-calculator',
#  'https://gpuvec.com/tools/model-speed-comparison',
#  'https://gpuvec.com/tools/gpus-as-weapons',
#  'https://gpuvec.com/tools/inference-speed',
#  'https://gpuvec.com/about',
#  'https://gpuvec.com/contact',
#  'https://gpuvec.com/llms',
#  'https://gpuvec.com/llms/compare',
#  'https://gpuvec.com/tools/qdrant-calculator',
#  'https://gpuvec.comembeddings',
#  'https://gpuvec.comembeddings/compare',
#  'https://gpuvec.com/gpus/h100',
#  'https://gpuvec.com/gpus/rtx-5000-ada',
#  'https://gpuvec.com/gpus/a5000',
#  'https://gpuvec.com/gpus/a6000',
#  'https://gpuvec.com/gpus/rtx-6000-ada',
#  'https://gpuvec.com/gpus/a100',
#  'https://gpuvec.com/gpus/a10',
#  'https://gpuvec.com/gpus/rtx-4090',
#  'https://gpuvec.com/gpus/rtx-3090',
#  'https://gpuvec.com/gpus/h200',
#  'https://gpuvec.com/gpus/rtx-5090',
#  'https://gpuvec.com/gpus/rtx-a4000',
#  'https://gpuvec.com/gpus/a30',
#  'https://gpuvec.com/gpus/tesla-v100',
#  'https://gpuvec.com/gpus/rtx-a4500',
#  'https://gpuvec.com/gpus/a40',
#  'https://gpuvec.com/gpus/tesla-t4',
#  'https://gpuvec.com/gpus/quadro-m4000',
#  'https://gpuvec.com/gpus/quadro-p4000',
#  'https://gpuvec.com/gpus/a16',
#  'https://gpuvec.com/gpus/l4',
#  'https://gpuvec.com/gpus/tesla-m60',
#  'https://gpuvec.com/gpus/tesla-p100',
#  'https://gpuvec.com/gpus/gh200-grace-hopper',
#  'https://gpuvec.com/gpus/dgx-b200',
#  'https://gpuvec.com/gpus/jetson-thor',
#  'https://gpuvec.com/providers/coreweave',
#  'https://gpuvec.com/providers/datacrunch',
#  'https://gpuvec.com/providers/hyperbolic',
#  'https://gpuvec.com/providers/hyperstack',
#  'https://gpuvec.com/providers/jarvislabs',
#  'https://gpuvec.com/providers/lambda',
#  'https://gpuvec.com/providers/lightning',
#  'https://gpuvec.com/providers/modal',
#  'https://gpuvec.com/providers/runpod',
#  'https://gpuvec.com/providers/saladcloud',
#  'https://gpuvec.com/providers/thundercompute',
#  'https://gpuvec.com/providers/vast',
#  'https://gpuvec.com/posts/top-gpu-providers-2025',
#  'https://gpuvec.com/posts/huawei_and_deepseek']

# %%
#| hide
#| eval: false
urls =['http://127.0.0.1:5001/',
 'http://127.0.0.1:5001/posts',
 'http://127.0.0.1:5001/gpus',
 'http://127.0.0.1:5001/providers',
 'http://127.0.0.1:5001/tools',
 'http://127.0.0.1:5001/tools/gpu-comparison',
 'http://127.0.0.1:5001/tools/model-size-calculator',
 'http://127.0.0.1:5001/tools/cost-estimator',
 'http://127.0.0.1:5001/compute_capability',
 'http://127.0.0.1:5001/tools/vector-database',
 'http://127.0.0.1:5001/tools/provider-comparison',
 'http://127.0.0.1:5001/tools/inference-comparison',
 'http://127.0.0.1:5001/tools/performance-calculator',
 'http://127.0.0.1:5001/tools/model-speed-comparison',
 'http://127.0.0.1:5001/tools/gpus-as-weapons',
 'http://127.0.0.1:5001/tools/inference-speed',
 'http://127.0.0.1:5001/about',
 'http://127.0.0.1:5001/contact',
 'http://127.0.0.1:5001/llms',
 'http://127.0.0.1:5001/llms/compare',
 'http://127.0.0.1:5001/tools/qdrant-calculator',
 'http://127.0.0.1:5001/embeddings',
 'http://127.0.0.1:5001/embeddings/compare',
 'http://127.0.0.1:5001/gpus/h100',
 'http://127.0.0.1:5001/gpus/rtx-5000-ada',
 'http://127.0.0.1:5001/gpus/a5000',
 'http://127.0.0.1:5001/gpus/a6000',
 'http://127.0.0.1:5001/gpus/rtx-6000-ada',
 'http://127.0.0.1:5001/gpus/a100',
 'http://127.0.0.1:5001/gpus/a10',
 'http://127.0.0.1:5001/gpus/rtx-4090',
 'http://127.0.0.1:5001/gpus/rtx-3090',
 'http://127.0.0.1:5001/gpus/h200',
 'http://127.0.0.1:5001/gpus/rtx-5090',
 'http://127.0.0.1:5001/gpus/rtx-a4000',
 'http://127.0.0.1:5001/gpus/a30',
 'http://127.0.0.1:5001/gpus/tesla-v100',
 'http://127.0.0.1:5001/gpus/rtx-a4500',
 'http://127.0.0.1:5001/gpus/a40',
 'http://127.0.0.1:5001/gpus/tesla-t4',
 'http://127.0.0.1:5001/gpus/quadro-m4000',
 'http://127.0.0.1:5001/gpus/quadro-p4000',
 'http://127.0.0.1:5001/gpus/a16',
 'http://127.0.0.1:5001/gpus/l4',
 'http://127.0.0.1:5001/gpus/tesla-m60',
 'http://127.0.0.1:5001/gpus/tesla-p100',
 'http://127.0.0.1:5001/gpus/gh200-grace-hopper',
 'http://127.0.0.1:5001/gpus/dgx-b200',
 'http://127.0.0.1:5001/gpus/jetson-thor',
 'http://127.0.0.1:5001/providers/coreweave',
 'http://127.0.0.1:5001/providers/datacrunch',
 'http://127.0.0.1:5001/providers/hyperbolic',
 'http://127.0.0.1:5001/providers/hyperstack',
 'http://127.0.0.1:5001/providers/jarvislabs',
 'http://127.0.0.1:5001/providers/lambda',
 'http://127.0.0.1:5001/providers/lightning',
 'http://127.0.0.1:5001/providers/modal',
 'http://127.0.0.1:5001/providers/runpod',
 'http://127.0.0.1:5001/providers/saladcloud',
 'http://127.0.0.1:5001/providers/thundercompute',
 'http://127.0.0.1:5001/providers/vast',
 'http://127.0.0.1:5001/posts/top-gpu-providers-2025',
 'http://127.0.0.1:5001/posts/huawei_and_deepseek']

# %%
#| hide
#| eval: false
all_results = validate_pages(urls)

# %%
#| hide
#| eval: false
for res in all_results:
    summary = res["summary"]
    status_icon = "✅" if summary["valid_count"] == summary["total_schemas"] and summary["total_schemas"] > 0 else (
        "⚠️" if summary["total_schemas"] > 0 else "❌")
    url_short = res["url"].replace("http://localhost:4321", "")
    print(
        f"{status_icon} {url_short or '/':<45} schemas:{summary['total_schemas']}  valid:{summary['valid_count']}  types:{summary['types_found']}")
    for schema in res["schemas_found"]:
        if schema["fields_missing_required"] or schema["warnings"]:
            print(
                f" └─ {schema['type']}: missing_required={schema['fields_missing_required']}  warnings={schema['warnings']}")
# Out:
# ✅ http://127.0.0.1:5001/                        schemas:1  valid:1  types:['WebPage']
# ✅ http://127.0.0.1:5001/posts                   schemas:2  valid:2  types:['Blog', 'WebPage']
#  └─ Blog: missing_required=[]  warnings=["'Blog' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/gpus                    schemas:3  valid:3  types:['ItemList', 'WebPage', 'ItemList']
# ✅ http://127.0.0.1:5001/providers               schemas:1  valid:1  types:['ItemList']
# ✅ http://127.0.0.1:5001/tools                   schemas:3  valid:3  types:['WebPage', 'SoftwareApplication', 'ItemList']
# ✅ http://127.0.0.1:5001/tools/gpu-comparison    schemas:2  valid:2  types:['WebPage', 'SoftwareApplication']
# ✅ http://127.0.0.1:5001/tools/model-size-calculator schemas:2  valid:2  types:['WebPage', 'SoftwareApplication']
# ✅ http://127.0.0.1:5001/tools/cost-estimator    schemas:2  valid:2  types:['WebPage', 'SoftwareApplication']
# ✅ http://127.0.0.1:5001/compute_capability      schemas:3  valid:3  types:['FAQPage', 'TechArticle', 'BreadcrumbList']
#  └─ TechArticle: missing_required=[]  warnings=["'TechArticle' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/tools/vector-database   schemas:2  valid:2  types:['WebPage', 'SoftwareApplication']
# ✅ http://127.0.0.1:5001/tools/provider-comparison schemas:2  valid:2  types:['WebPage', 'SoftwareApplication']
# ✅ http://127.0.0.1:5001/tools/inference-comparison schemas:2  valid:2  types:['WebPage', 'SoftwareApplication']
# ✅ http://127.0.0.1:5001/tools/performance-calculator schemas:2  valid:2  types:['WebPage', 'SoftwareApplication']
# ✅ http://127.0.0.1:5001/tools/model-speed-comparison schemas:2  valid:2  types:['WebPage', 'SoftwareApplication']
# ✅ http://127.0.0.1:5001/tools/gpus-as-weapons   schemas:2  valid:2  types:['WebPage', 'SoftwareApplication']
# ✅ http://127.0.0.1:5001/tools/inference-speed   schemas:2  valid:2  types:['WebPage', 'SoftwareApplication']
# ✅ http://127.0.0.1:5001/about                   schemas:4  valid:4  types:['Organization', 'WebSite', 'AboutPage', 'WebPage']
#  └─ AboutPage: missing_required=[]  warnings=["'AboutPage' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/contact                 schemas:4  valid:4  types:['Organization', 'WebSite', 'ContactPage', 'WebPage']
#  └─ ContactPage: missing_required=[]  warnings=["'ContactPage' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/llms                    schemas:3  valid:3  types:['ItemList', 'WebPage', 'FAQPage']
# ❌ http://127.0.0.1:5001/llms/compare            schemas:0  valid:0  types:[]
# ❌ http://127.0.0.1:5001/tools/qdrant-calculator schemas:0  valid:0  types:[]
# ✅ http://127.0.0.1:5001/embeddings              schemas:2  valid:2  types:['ItemList', 'WebPage']
# ❌ http://127.0.0.1:5001/embeddings/compare      schemas:0  valid:0  types:[]
# ✅ http://127.0.0.1:5001/gpus/h100               schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/rtx-5000-ada       schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/a5000              schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/a6000              schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/rtx-6000-ada       schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/a100               schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/a10                schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/rtx-4090           schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/rtx-3090           schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/h200               schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/rtx-5090           schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/rtx-a4000          schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/a30                schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/tesla-v100         schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/rtx-a4500          schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/a40                schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/tesla-t4           schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/quadro-m4000       schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/quadro-p4000       schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/a16                schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/l4                 schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/tesla-m60          schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/tesla-p100         schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/gh200-grace-hopper schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/dgx-b200           schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/gpus/jetson-thor        schemas:1  valid:1  types:['Product']
# ✅ http://127.0.0.1:5001/providers/coreweave     schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/datacrunch    schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/hyperbolic    schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/hyperstack    schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/jarvislabs    schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/lambda        schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/lightning     schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/modal         schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/runpod        schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/saladcloud    schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/thundercompute schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/providers/vast          schemas:3  valid:3  types:['Organization', 'Service', 'BreadcrumbList']
#  └─ Service: missing_required=[]  warnings=["'Service' is not a Google rich result type — no rich snippet will be generated"]
# ✅ http://127.0.0.1:5001/posts/top-gpu-providers-2025 schemas:1  valid:1  types:['FAQPage']
# ✅ http://127.0.0.1:5001/posts/huawei_and_deepseek schemas:1  valid:1  types:['FAQPage']
